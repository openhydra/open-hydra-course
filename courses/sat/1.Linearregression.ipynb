# %% [markdown]
# # 用线性回归（BaseML）训练SAT-GPA成绩预测模型
#
#
# ## 1.数据集说明
#
# 一个最简单的入门的线性回归的 machine learn 的课程，通过入学考试成绩（SAT）来推测这些学生的毕业成绩（GPA），数据源都是来自于特定时间的真实数据。
#
# ## 2.代码实现
#
# 使用BaseML的线性回归算法（LinearRegression）。
#
# ### 2.1 训练模型

# %%
# 建议先更新库文件
# !pip install --upgrade BaseML
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Attempting uninstall: BaseML
#     Found existing installation: BaseML 0.0.7
#     Uninstalling BaseML-0.0.7:
#       Successfully uninstalled BaseML-0.0.7
# ...

# %%
# 导入库文件，选择回归模块
from BaseML import Regression as reg
# 构建线性回归模型
model = reg(algorithm = 'LinearRegression')
# 从某路径载入数据集
model.load_tab_data('data.csv')        # 在此空填入数据集路径
# 训练模型
model.train()
# 将模型保存至1.mymodel.pkl
model.save('1.mymodel.pkl')
# Out:
# Saving model checkpoints...
# Saved successfully!

# %% [markdown]
# 因为没有做测试集，于是把原训练数据作为测试集验证一下效果。

# %%
# 读取数据计算R平方值
r2_Linear, result = model.valid('data.csv', metrics='r2') # 载入验证数据
model.metricplot() # 可视化验证效果
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# 验证r2-score为：40.600391479679764%

# %% [markdown]
# ### 2.2 模型预测

# %%
from BaseML import Regression as reg
model = reg(algorithm = 'LinearRegression')
model.load('1.mymodel.pkl')
data = float(input('请输入一个新的SAT成绩：'))
y = model.inference([data])
print('该学生的GPA成绩可能为：', y[0])
# Out:
# 请输入一个新的SAT成绩：2000
# 该学生的GPA成绩可能为： 3.586416399845908
